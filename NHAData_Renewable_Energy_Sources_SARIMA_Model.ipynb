# %%
pip install matplotlib windrose

# %%
# imports

import pandas as pd
import sys, os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from windrose import WindroseAxes
from google.colab import drive

# %%
# mount drive

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # NHA Data

# %%
# read data

NHA_data_path = '/content/drive/My Drive/Capstone_P1_Data/NHADamData.csv'
df_NHA_data = pd.read_csv(NHA_data_path)

# %%
df_NHA_data['Name'] = df_NHA_data['Name'].astype(str)
df_NHA_data['Owner'] = df_NHA_data['Owner'].astype(str)
df_NHA_data['Hydro?'] = df_NHA_data['Hydro?'].astype(str)
df_NHA_data['Type'] = df_NHA_data['Type'].astype(str)
df_NHA_data['Capacity'] = df_NHA_data['Capacity'].astype(float)

# %%
# Capacity boxplot

sns.boxplot(x='Capacity',data=df_NHA_data)
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=100))
plt.title('Capacity Range')
plt.show()

# %%
# Capacity Box Plot Conventional Hydro

df_NHA_data_only_conv = df_NHA_data[df_NHA_data['Type'] == 'Conventional Hydro']

sns.boxplot(x='Capacity',data=df_NHA_data_only_conv)
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=10))
plt.title('Capacity Range of Convential Hydro Dams')
plt.show()

# %%
# Capacity Box Plot Pumped Storage


df_NHA_data_only_pumped_storage = df_NHA_data[df_NHA_data['Type'] == 'Pumped Storage']

sns.boxplot(x='Capacity',data=df_NHA_data_only_pumped_storage)
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=100))
plt.title('Capacity Range of Pumped Storage Dams')
plt.show()

# %%
# Capacity Box Plot Non Powered

df_NHA_data_non_powered = df_NHA_data[df_NHA_data['Type'] == 'nan']

sns.boxplot(x='Capacity',data=df_NHA_data_non_powered)
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.title('Capacity Range of Non-powered Dams')
plt.show()

# %%
sns.countplot(x='Hydro?', data=df_NHA_data)

plt.xlabel('Hydro?')
plt.ylabel('Count')
plt.title('Powered vs Non-powered Dams')
plt.show()

# %% [markdown]
# # NSRDB

# %%
# Read In Files

columns_to_read = ['Year','Month','Day','Hour','Minute','Temperature','Dew Point','GHI','Relative Humidity', 'Pressure', 'Wind Direction', 'Wind Speed']

Boston21_data_path = '/content/drive/My Drive/Capstone_P1_Data/Boston_Solar_2021_Official.csv'
df_Boston21 = pd.read_csv(Boston21_data_path, usecols=columns_to_read)

Boston20_data_path = '/content/drive/My Drive/Capstone_P1_Data/Boston_Solar_2020_Official.csv'
df_Boston20 = pd.read_csv(Boston20_data_path, usecols=columns_to_read)

Boston19_data_path = '/content/drive/My Drive/Capstone_P1_Data/Boston_Solar_2019_Official.csv'
df_Boston19 = pd.read_csv(Boston19_data_path, usecols=columns_to_read)

Boston18_data_path = '/content/drive/My Drive/Capstone_P1_Data/Boston_Solar_2018_Official.csv'
df_Boston18 = pd.read_csv(Boston18_data_path, usecols=columns_to_read)

Beverly21_data_path = '/content/drive/My Drive/Capstone_P1_Data/Beverly_Solar_2021_Official.csv'
df_Beverly21 = pd.read_csv(Beverly21_data_path, usecols=columns_to_read)

Beverly20_data_path = '/content/drive/My Drive/Capstone_P1_Data/Beverly_Solar_2020_Official.csv'
df_Beverly20 = pd.read_csv(Beverly20_data_path, usecols=columns_to_read)

Beverly19_data_path = '/content/drive/My Drive/Capstone_P1_Data/Beverly_Solar_2019_Official.csv'
df_Beverly19 = pd.read_csv(Beverly19_data_path, usecols=columns_to_read)

Beverly18_data_path = '/content/drive/My Drive/Capstone_P1_Data/Beverly_Solar_2018_Official.csv'
df_Beverly18 = pd.read_csv(Beverly18_data_path, usecols=columns_to_read)

Chicopee21_data_path = '/content/drive/My Drive/Capstone_P1_Data/Chicopee_Solar_2021_Official.csv'
df_Chicopee21 = pd.read_csv(Chicopee21_data_path, usecols=columns_to_read)

Chicopee20_data_path = '/content/drive/My Drive/Capstone_P1_Data/Chicopee_Solar_2020_Official.csv'
df_Chicopee20 = pd.read_csv(Chicopee20_data_path, usecols=columns_to_read)

Chicopee19_data_path = '/content/drive/My Drive/Capstone_P1_Data/Chicopee_Solar_2019_Official.csv'
df_Chicopee19 = pd.read_csv(Chicopee19_data_path, usecols=columns_to_read)

Chicopee18_data_path = '/content/drive/My Drive/Capstone_P1_Data/Chicopee_Solar_2018_Official.csv'
df_Chicopee18 = pd.read_csv(Chicopee18_data_path, usecols=columns_to_read)

Falmouth21_data_path = '/content/drive/My Drive/Capstone_P1_Data/Falmouth_Solar_2021_Official.csv'
df_Falmouth21 = pd.read_csv(Falmouth21_data_path, usecols=columns_to_read)

Falmouth20_data_path = '/content/drive/My Drive/Capstone_P1_Data/Falmouth_Solar_2020_Official.csv'
df_Falmouth20 = pd.read_csv(Falmouth20_data_path, usecols=columns_to_read)

Falmouth19_data_path = '/content/drive/My Drive/Capstone_P1_Data/Falmouth_Solar_2019_Official.csv'
df_Falmouth19 = pd.read_csv(Falmouth19_data_path, usecols=columns_to_read)

Falmouth18_data_path = '/content/drive/My Drive/Capstone_P1_Data/Falmouth_Solar_2018_Official.csv'
df_Falmouth18 = pd.read_csv(Falmouth18_data_path, usecols=columns_to_read)

Sturbridge21_data_path = '/content/drive/My Drive/Capstone_P1_Data/Sturbridge_Solar_2021_Official.csv'
df_Sturbridge21 = pd.read_csv(Sturbridge21_data_path, usecols=columns_to_read)

Sturbridge20_data_path = '/content/drive/My Drive/Capstone_P1_Data/Sturbridge_Solar_2020_Official.csv'
df_Sturbridge20 = pd.read_csv(Sturbridge20_data_path, usecols=columns_to_read)

Sturbridge19_data_path = '/content/drive/My Drive/Capstone_P1_Data/Sturbridge_Solar_2019_Official.csv'
df_Sturbridge19 = pd.read_csv(Sturbridge19_data_path, usecols=columns_to_read)

Sturbridge18_data_path = '/content/drive/My Drive/Capstone_P1_Data/Sturbridge_Solar_2018_Official.csv'
df_Sturbridge18 = pd.read_csv(Sturbridge18_data_path, usecols=columns_to_read)

# %%
df_Boston_Solar = pd.concat([df_Boston18, df_Boston19, df_Boston20, df_Boston21], ignore_index=True)

df_Beverly_Solar = pd.concat([df_Beverly18, df_Beverly19, df_Beverly20, df_Beverly21], ignore_index=True)

df_Chicopee_Solar = pd.concat([df_Chicopee18, df_Chicopee19, df_Chicopee20, df_Chicopee21], ignore_index=True)

df_Falmouth_Solar = pd.concat([df_Falmouth18, df_Falmouth19, df_Falmouth20, df_Falmouth21], ignore_index=True)

df_Sturbridge_Solar = pd.concat([df_Sturbridge18, df_Sturbridge19, df_Sturbridge20, df_Sturbridge21], ignore_index=True)

# %%
df_Boston_Solar['DateTime'] = pd.to_datetime(df_Boston_Solar[['Year','Month','Day','Hour','Minute']])
df_Boston_Solar.set_index('DateTime', inplace=True)
df_Boston_Solar.drop(columns=['Year','Month','Day','Hour','Minute'], inplace=True)

df_Boston_Solar_rolling = df_Boston_Solar.resample('W').mean()
df_Boston_Solar_rolling['City'] = 'Boston'


df_Beverly_Solar['DateTime'] = pd.to_datetime(df_Beverly_Solar[['Year','Month','Day','Hour','Minute']])
df_Beverly_Solar.set_index('DateTime', inplace=True)
df_Beverly_Solar.drop(columns=['Year','Month','Day','Hour','Minute'], inplace=True)

df_Beverly_Solar_rolling = df_Beverly_Solar.resample('W').mean()
df_Beverly_Solar_rolling['City'] = 'Beverly'


df_Chicopee_Solar['DateTime'] = pd.to_datetime(df_Chicopee_Solar[['Year','Month','Day','Hour','Minute']])
df_Chicopee_Solar.set_index('DateTime', inplace=True)
df_Chicopee_Solar.drop(columns=['Year','Month','Day','Hour','Minute'], inplace=True)

df_Chicopee_Solar_rolling = df_Chicopee_Solar.resample('W').mean()
df_Chicopee_Solar_rolling['City'] = 'Chicopee'

df_Falmouth_Solar['DateTime'] = pd.to_datetime(df_Falmouth_Solar[['Year','Month','Day','Hour','Minute']])
df_Falmouth_Solar.set_index('DateTime', inplace=True)
df_Falmouth_Solar.drop(columns=['Year','Month','Day','Hour','Minute'], inplace=True)

df_Falmouth_Solar_rolling = df_Boston_Solar.resample('W').mean()
df_Falmouth_Solar_rolling['City'] = 'Falmouth'

df_Sturbridge_Solar['DateTime'] = pd.to_datetime(df_Sturbridge_Solar[['Year','Month','Day','Hour','Minute']])
df_Sturbridge_Solar.set_index('DateTime', inplace=True)
df_Sturbridge_Solar.drop(columns=['Year','Month','Day','Hour','Minute'], inplace=True)

df_Sturbridge_Solar_rolling = df_Sturbridge_Solar.resample('W').mean()
df_Sturbridge_Solar_rolling['City'] = 'Sturbridge'

# %%
df_Solar = pd.concat([df_Boston_Solar_rolling, df_Beverly_Solar_rolling, df_Chicopee_Solar_rolling, df_Falmouth_Solar_rolling, df_Sturbridge_Solar_rolling], ignore_index=True)

# %% [markdown]
# ## Visualizations

# %%
## change this to df_All_Solar_rolling once other data is loaded in

sns.boxplot(x='Temperature',data=df_Solar)
plt.title('Rolling Mean Temperature')
plt.show()

# %%
sns.boxplot(x='Dew Point',data=df_Solar)
plt.title('Rolling Mean of Temperature')
plt.show()

# %%
sns.boxplot(x='GHI',data=df_Solar)
plt.title('Rolling Mean of GHI')
plt.show()

# %%
sns.boxplot(x='Relative Humidity',data=df_Solar)
plt.title('Rolling Mean of Relative Humidity')
plt.show()

# %%
sns.boxplot(x='Pressure',data=df_Solar)
plt.title('Rolling Mean of Pressure')
plt.show()

# %%
sns.boxplot(x='Wind Speed',data=df_Solar)
plt.title('Rolling Mean of Wind Speed')
plt.show()

# %%
ax = WindroseAxes.from_ax()
ax.bar(df_Solar['Wind Direction'], df_Solar['Wind Speed'], normed=True, opening=0.8, edgecolor='white')
ax.set_legend()
plt.show()

# %%
ax = WindroseAxes.from_ax()
ax.bar(df_Boston_Solar_rolling['Wind Direction'], df_Boston_Solar_rolling['Wind Speed'], normed=True, opening=0.8, edgecolor='white')
ax.set_legend()
plt.title('Boston Wind Behavior')
plt.show()

# %%
sns.lineplot(x=df_Solar.DateTime, y=df_Solar['Temperature'], hue=df_Solar['City'])
plt.title('Temperature Per City')
plt.xticks(rotation=45)
plt.show()

# %%
sns.lineplot(x=df_Solar.DateTime, y=df_Solar['GHI'], hue=df_Solar['City'])
plt.title('GHI Per City')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.show()

# %%
sns.lineplot(x=df_Solar.DateTime, y=df_Solar['Dew Point'], hue=df_Solar['City'])
plt.title('Dew Point Per City')
plt.xticks(rotation=45)
plt.show()

# %%
sns.lineplot(x=df_Solar.DateTime, y=df_Solar['Relative Humidity'], hue=df_Solar['City'])
plt.title('Relative Humidity Per City')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.show()

# %%
sns.lineplot(x=df_Solar.DateTime, y=df_Solar['Pressure'], hue=df_Solar['City'])
plt.title('Pressure Per City')
plt.xticks(rotation=45)
plt.show()

# %%
sns.lineplot(x=df_Solar.DateTime, y=df_Solar['Wind Speed'], hue=df_Solar['City'])
plt.title('Wind Speed Per City')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.show()

# %%
df_Solar_Boston = df_Solar[df_Solar['City'] == 'Boston']
sns.lineplot(x=df_Solar_Boston.DateTime, y=df_Solar_Boston['Wind Speed'], hue=df_Solar['City'])
plt.title('Wind Speed Per City')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.show()

# %%
df_Boston_Solar_rolling.iloc[20:25].head()
# Out:
#      DateTime  Temperature  Dew Point        GHI  Relative Humidity  \
# 20 2018-01-21    -1.280060  -3.286310  78.464286          86.767560
# 21 2018-01-22    -0.661012  -2.597619  75.550595          87.286935
# 22 2018-01-23    -0.171429  -2.020536  68.761905          87.891637
# 23 2018-01-24     0.255655  -1.644345  67.553571          87.702054
# 24 2018-01-25    -0.182440  -2.509226  72.369048          85.167232
#
#        Pressure  Wind Direction  Wind Speed    City
# 20  1018.366071      230.098214    1.225298  Boston
# 21  1018.500000      224.863095    1.179464  Boston
# 22  1018.160714      217.422619    1.168155  Boston
# 23  1016.565476      218.526786    1.205060  Boston
# 24  1016.223214      226.309524    1.247917  Boston

# %%
df_Solar.iloc[20:25].head()
# Out:
#      DateTime  Temperature  Dew Point        GHI  Relative Humidity  \
# 20 2018-01-21    -1.280060  -3.286310  78.464286          86.767560
# 21 2018-01-22    -0.661012  -2.597619  75.550595          87.286935
# 22 2018-01-23    -0.171429  -2.020536  68.761905          87.891637
# 23 2018-01-24     0.255655  -1.644345  67.553571          87.702054
# 24 2018-01-25    -0.182440  -2.509226  72.369048          85.167232
#
#        Pressure  Wind Direction  Wind Speed    City
# 20  1018.366071      230.098214    1.225298  Boston
# 21  1018.500000      224.863095    1.179464  Boston
# 22  1018.160714      217.422619    1.168155  Boston
# 23  1016.565476      218.526786    1.205060  Boston
# 24  1016.223214      226.309524    1.247917  Boston

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import numpy as np

# Plotting the time series
plt.figure(figsize=(12, 6))
plt.plot(df_Boston_Solar_rolling.index, df_Boston_Solar_rolling["Wind Speed"])
plt.title('Time Series Plot')
plt.xlabel('Date')
plt.ylabel('Wind Speed')
plt.show()

# %%
df_Boston_Solar_rolling
# Out:
#             Temperature  Dew Point        GHI  Relative Humidity     Pressure  \
# DateTime
# 2018-01-07   -11.418452 -13.326786  86.511905          86.302857  1012.994048
# 2018-01-14    -0.136905  -2.033929  80.416667          87.665357  1018.041667
# 2018-01-21    -2.423214  -4.538690  76.511905          85.869762  1018.690476
# 2018-01-28     0.877381  -1.845238  70.625000          83.411012  1018.720238
# 2018-02-04    -2.611310  -5.610714  80.940476          80.613036  1015.577381
# ...                 ...        ...        ...                ...          ...
# 2021-12-05     2.294643  -1.226190  74.946429          79.056786  1011.208333
# 2021-12-12     4.270238   1.216667  52.065476          81.575595  1012.666667
# 2021-12-19     5.081548   1.719643  54.410714          80.016429  1017.785714
# 2021-12-26    -0.827381  -3.707143  47.178571          81.830774  1010.410714
# 2022-01-02     1.795000   0.557500  31.858333          91.723167  1010.350000
#
# ...

# %%
from statsmodels.tsa.stattools import adfuller

# Check for stationarity
result = adfuller(df_Boston_Solar_rolling["Wind Speed"])
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')

# Differencing
df_diff = df_Boston_Solar_rolling["Wind Speed"].diff().dropna()

result_diff = adfuller(df_diff)
print(f'ADF Statistic (after differencing): {result_diff[0]}')
print(f'p-value (after differencing): {result_diff[1]}')
# Out:
# ADF Statistic: -4.487700341937076
# p-value: 0.00020695130764544027
# ADF Statistic (after differencing): -4.898625520398223
# p-value (after differencing): 3.508983646039025e-05

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 8))
plot_acf(df_diff, lags=52, ax=ax[0])
plot_pacf(df_diff, lags=52, ax=ax[1])
plt.show()

# %%
import itertools
import numpy as np
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Split the data into train and test sets
train_size = int(len(df_Boston_Solar_rolling[["Wind Speed"]]) * 0.75)
train, test = df_Boston_Solar_rolling[["Wind Speed"]][:train_size], df_Boston_Solar_rolling[["Wind Speed"]][train_size:]

# Define the parameter ranges to test
p_values = range(0, 3)
d_values = range(0, 2)
q_values = range(0, 3)
P_values = range(0, 2)
D_values = range(0, 2)
Q_values = range(0, 2)
s_values = [52]

# Function to fit the model and calculate MSE
def fit_sarima_model(train, test, p, d, q, P, D, Q, s):
    model = SARIMAX(train, order=(p, d, q), seasonal_order=(P, D, Q, s))
    results = model.fit(disp=False)
    test_forecast = results.get_forecast(steps=len(test)).predicted_mean
    mse = mean_squared_error(test, test_forecast)
    return mse, results

# Initialize variables to store the best parameters and lowest MSE
best_mse = float('inf')
best_params = None
best_model = None

# Loop through all parameter combinations
for p, d, q, P, D, Q, s in itertools.product(p_values, d_values, q_values, P_values, D_values, Q_values, s_values):
    try:
        mse, results = fit_sarima_model(train, test, p, d, q, P, D, Q, s)
        if mse < best_mse:
            best_mse = mse
            best_params = (p, d, q, P, D, Q, s)
            best_model = results
        print(f'ARIMA({p},{d},{q})x({P},{D},{Q},{s}) - MSE: {mse}')
    except Exception as e:
        print(f'Error fitting ARIMA({p},{d},{q})x({P},{D},{Q},{s}): {e}')

# Print the best parameters and their corresponding MSE
print(f'Best model: ARIMA{best_params} - MSE: {best_mse}')

# Plot the results of the best model
test_forecast = best_model.get_forecast(steps=len(test)).predicted_mean

plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Test')
plt.plot(test.index, test_forecast, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Wind Speed')
plt.title(f'Wind Speed Forecast vs Actual - Best Model: ARIMA{best_params}')
plt.legend()
plt.show()
# Out:
# ARIMA(0,0,0)x(0,0,0,52) - MSE: 0.8618433863325204
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(0,0,0)x(0,0,1,52) - MSE: 0.2525954923126228
# ARIMA(0,0,0)x(0,1,0,52) - MSE: 0.03157594366362896
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(0,0,0)x(0,1,1,52) - MSE: 0.027254962788947693
# ARIMA(0,0,0)x(1,0,0,52) - MSE: 0.030975903965610313
# ...

# %%
train_size = int(len(df_Boston_Solar_rolling[["Wind Speed"]]) * 0.75)
train, test = df_Boston_Solar_rolling[["Wind Speed"]][:train_size], df_Boston_Solar_rolling[["Wind Speed"]][train_size:]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Define the parameters you want to test
p = 1
d = 1
q = 1
P = 1
D = 1
Q = 1
s = 52

# Create the model with the specified parameters
model = SARIMAX(train, order=(p, d, q), seasonal_order=(P, D, Q, s))

# Fit the model
results = model.fit(disp=False)

# Print the model's AIC
print(f'ARIMA({p},{d},{q})x({P},{D},{Q},{s}) - AIC: {results.aic}')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(1,1,1)x(1,1,1,52) - AIC: -62.329666595309845

# %%
from sklearn.metrics import mean_squared_error
test_forecast = results.get_forecast(steps=len(test)).predicted_mean

# Calculate the Mean Squared Error (MSE)
mse = mean_squared_error(test, test_forecast)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 0.026921370792286438

# %%
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Test')
plt.plot(test.index, test_forecast, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Wind Speed')
plt.title('Wind Speed Forecast vs Actual')
plt.legend()
plt.show()

# %%
# Define the parameters you want to test
p = 0
d = 0
q = 0
P = 0
D = 0
Q = 1
s = 52

# Create the model with the specified parameters
model = SARIMAX(train, order=(p, d, q), seasonal_order=(P, D, Q, s))

# Fit the model
results = model.fit(disp=False)

# Print the model's AIC
print(f'ARIMA({p},{d},{q})x({P},{D},{Q},{s}) - AIC: {results.aic}')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# ARIMA(0,0,0)x(0,0,1,52) - AIC: 336.354596129066

# %%
test_forecast = results.get_forecast(steps=len(test)).predicted_mean

# Calculate the Mean Squared Error (MSE)
mse = mean_squared_error(test, test_forecast)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 0.24687421927938075

# %%
# Define the parameters you want to test
p = 0
d = 1
q = 1
P = 0
D = 1
Q = 1
s = 52

# Create the model with the specified parameters
model = SARIMAX(train, order=(p, d, q), seasonal_order=(P, D, Q, s))

# Fit the model
results = model.fit(disp=False)

# Print the model's AIC
print(f'ARIMA({p},{d},{q})x({P},{D},{Q},{s}) - AIC: {results.aic}')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(0,1,1)x(0,1,1,52) - AIC: -57.595530393544514

# %%
test_forecast = results.get_forecast(steps=len(test)).predicted_mean

# Calculate the Mean Squared Error (MSE)
mse = mean_squared_error(test, test_forecast)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 0.027413843578595436

# %%
from statsmodels.tsa.stattools import adfuller

# Check for stationarity
result = adfuller(df_Boston_Solar_rolling["GHI"])
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')

# Differencing
df_diff = df_Boston_Solar_rolling["GHI"].diff().dropna()

result_diff = adfuller(df_diff)
print(f'ADF Statistic (after differencing): {result_diff[0]}')
print(f'p-value (after differencing): {result_diff[1]}')
# Out:
# ADF Statistic: -5.6350639911906395
# p-value: 1.0677346378110503e-06
# ADF Statistic (after differencing): -3.9796661872996175
# p-value (after differencing): 0.001520808709777544

# %%
train_size = int(len(df_Boston_Solar_rolling[["GHI"]]) * 0.75)
train, test = df_Boston_Solar_rolling[["GHI"]][:train_size], df_Boston_Solar_rolling[["GHI"]][train_size:]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Define the parameters you want to test
p = 1
d = 1
q = 1
P = 1
D = 1
Q = 1
s = 52

# Create the model with the specified parameters
model = SARIMAX(train, order=(p, d, q), seasonal_order=(P, D, Q, s))

# Fit the model
results = model.fit(disp=False)

# Print the model's AIC
print(f'ARIMA({p},{d},{q})x({P},{D},{Q},{s}) - AIC: {results.aic}')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(1,1,1)x(1,1,1,52) - AIC: 1051.6176152606895

# %%
from sklearn.metrics import mean_squared_error

test_forecast = results.get_forecast(steps=len(test)).predicted_mean

# Calculate the Mean Squared Error (MSE)
mse = mean_squared_error(test, test_forecast)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 1370.4425029059232

# %%
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Test')
plt.plot(test.index, test_forecast, label='Forecast')
plt.xlabel('Date')
plt.ylabel('GHI')
plt.title('GHI Forecast vs Actual')
plt.legend()
plt.show()

# %%
print(test_forecast)

# %%
# Calculate the minimum cost
C_s = 3.51  # Solar installation cost ($/watt)
C_w = 1750  # Wind installation cost ($/kW)
C_h = 2000000  # Hydro installation cost (assumption)

# Hydro energy production already done
hydro_dams = df_NHA_data[df_NHA_data['Hydro?'] == 'Y']
done_hydro_capacity = hydro_dams['Capacity'].sum()
E_h_done = done_hydro_capacity * 8760
print(f"Hydro energy already installed is ({E_h_done:,.2f} kWh)")

# Energy demand
D = 60000000  # kWh/year (assumption)

# Check if hydro energy is sufficient to meet the demand
if E_h_done >= D:
    print(f"Hydro energy already installed ({E_h_done:,.2f} kWh) is sufficient to meet the energy demand ({D:,.2f} kWh).")
    print("No additional solar or wind energy is required.")
    sys.exit()
else:
    # Calculate the remaining energy demand after using hydro energy
    D = D - E_h_done

# Hydro energy production to be done
non_hydro_dams = df_NHA_data[df_NHA_data['Hydro?'] == 'N']
non_done_hydro_capacity = non_hydro_dams['Capacity'].sum()
E_h_non_done = non_done_hydro_capacity * 8760

# Calculate solar energy potential (P_s)
solar_panel_area = 1000  # Assumption: 1000 m^2 of solar panels
solar_panel_efficiency = 0.2  # Assumption: 20% efficiency
solar_loss_factor = 0.1  # Assumption: 10% loss factor
df_Boston_Solar_rolling['P_s'] = solar_panel_area * df_Boston_Solar_rolling['GHI'] * solar_panel_efficiency * (1 - solar_loss_factor)
solar_production = df_Boston_Solar_rolling['P_s'].sum()  # Total solar energy potential

# Calculate wind energy potential (P_w)
air_density = 1.225  # kg/m^3 (standard air density at sea level)
turbine_diameter = 50  # m (assumption)
turbine_efficiency = 0.7  # Assumption: 40% efficiency
swept_area = np.pi * (turbine_diameter / 2) ** 2  # m^2
df_Boston_Solar_rolling['P_w'] = 0.5 * air_density * swept_area * df_Boston_Solar_rolling['Wind Speed'] ** 3 * turbine_efficiency
wind_production = df_Boston_Solar_rolling['P_w'].sum()  # Total wind energy potential

print("The Energy generated from Solar energy in KWh:", solar_production)
print("The Energy generated from Wind energy in KWh:", wind_production)
print("The Energy generated from Hydro energy in KWh:", hydro_production)
print("Energy Demand:", D)


# Find the highest energy source
max_energy = max(solar_production, wind_production, hydro_production)
if max_energy == solar_production:
    highest_source = "Solar"
elif max_energy == wind_production:
    highest_source = "Wind"
else:
    highest_source = "hydro_production"

print(f"The highest energy source is {highest_source}.")

if highest_source == "Solar":
    req_demand = D - max_energy
    if req_demand > 0:
      max_of_two = max(hydro_production, wind_production)
      req_demand = req_demand - max_of_two
      if req_demand > 0:
        list_energy_values = [solar_production, wind_production, hydro_production]
        req_demand = req_demand - min(hydro_production, wind_production)
        req_energy = max_energy + max_of_two + min(hydro_production, wind_production)
        min_cost = C_s * solar_production * 1000 + C_w * wind_production + C_h * hydro_production
        list_prod = ['Solar', 'Wind', 'Hydro']
      else:
        req_energy = max_energy + max_of_two
        if max_of_two == hydro_production:
          min_cost = C_h * hydro_production + C_s * solar_production * 1000
          list_energy_values = [solar_production, hydro_production]
          list_prod = ['Solar', 'Hydro']
        else:
          min_cost = C_s * solar_production * 1000 + C_w * wind_production
          list_energy_values = [solar_production, wind_production]
          list_prod = ['Solar', 'Wind']
    else:
      req_energy = max_energy
      min_cost = C_w * solar_production * 1000
      list_prod = ['Solar']
      list_energy_values = [solar_production]
elif highest_source == wind_production:
    req_demand = D - max_energy
    if req_demand > 0:
      max_of_two = max(hydro_production, solar_production)
      req_demand = req_demand - max_of_two
      if req_demand > 0:
        req_demand = req_demand - min(hydro_production, solar_production)
        req_energy = max_energy + max_of_two + min(hydro_production, solar_production)
        min_cost = C_s * solar_production * 1000 + C_w * wind_production + C_h * hydro_production
        list_prod = ['Solar', 'Wind', 'Hydro']
        list_energy_values = [wind_production, solar_production, hydro_production]
      else:
        req_energy = max_energy + max_of_two
        if max_of_two == hydro_production:
          min_cost = C_w * wind_production + C_h * hydro_production
          list_prod = ['Wind', 'Hydro']
          list_energy_values = [wind_production, hydro_production]
        else:
          min_cost = C_s * solar_production * 1000 + C_w * wind_production
          list_prod = ['Solar', 'Wind']
          list_energy_values = [solar_production, wind_production]
    else:
      req_energy = max_energy
      min_cost = C_w * wind_production
      list_prod = ['Wind']
      list_energy_values = [wind_production]

else:
  req_demand = D - max_energy
  if req_demand > 0:
      max_of_two = max(solar_production, wind_production)
      req_demand = req_demand - max_of_two
      if req_demand > 0:
        req_demand = req_demand - min(solar_production, wind_production)
        req_energy = max_energy + max_of_two + min(solar_production, wind_production)
        min_cost = C_s * solar_production * 1000 + C_w * wind_production + C_h * hydro_production
        list_prod = ['Solar', 'Wind', 'Hydro']
        list_energy_values = [solar_production, wind_production, hydro_production]
      else:
        req_energy = max_energy + max_of_two
        if max_of_two == solar_production:
          min_cost = C_s * solar_production * 1000 + C_h * hydro_production
          list_prod = ['Solar', 'Hydro']
          list_energy_values = [solar_production, hydro_production]
        else:
          min_cost = C_h * hydro_production + C_w * wind_production
          list_prod = ['Wind', 'Hydro']
          list_energy_values = [wind_production, hydro_production]
  else:
      req_energy = max_energy
      min_cost = C_h * hydro_production
      list_prod = ['Hydro']
      list_energy_values = [hydro_production]
print("The total energy for the city is supplied by:", list_prod )
print("The total energy for the city generated through renewable sources is", req_energy)
print("The total cost for this project as a whole:", min_cost)

# %%
import matplotlib.pyplot as plt

# Existing hydro energy production
existing_hydro = E_h_done

# Energy demand
demand = D

# Create a bar chart
fig, ax = plt.subplots(figsize=(8, 6))
bars = ax.bar(['Existing Hydro', 'Energy Demand'], [existing_hydro, demand])
ax.bar_label(bars)
ax.set_ylabel('Energy (kWh)')
ax.set_title('Existing Hydro Energy Production vs. Energy Demand')

plt.show()

# %%
import matplotlib.pyplot as plt

# Potential energy production
sources = ['Solar', 'Wind', 'Additional Hydro']
production = [solar_production, wind_production, E_h_non_done]

# Create a pie chart
fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(production, labels=sources, autopct='%1.1f%%')
ax.axis('equal')
ax.set_title('Potential Energy Production from Different Sources')

plt.show()

# %%
import matplotlib.pyplot as plt

# Create a bar chart
fig, ax = plt.subplots(figsize=(8, 6))

# Define the sources
sources = ['Solar', 'Wind', 'Hydro']

# Convert all values to integers
int_list = [int(x) if isinstance(x, str) and x.isdigit() else x if isinstance(x, (int, float)) else 0 for x in list_energy_values]

bars = ax.bar(sources, int_list)
ax.bar_label(bars)
ax.set_ylabel('Energy (kWh)')
ax.set_title('Energy Production Breakdown')

plt.show()

# %%
# Calculate the minimum cost
C_s = 3.51  # Solar installation cost ($/watt)
C_w = 1750  # Wind installation cost ($/kW)
C_h = 2000000  # Hydro installation cost (assumption)

# Hydro energy production already done
hydro_dams = df_NHA_data[df_NHA_data['Hydro?'] == 'Y']
done_hydro_capacity = hydro_dams['Capacity'].sum()
E_h_done = done_hydro_capacity * 8760
print(f"Hydro energy already installed is ({E_h_done:,.2f} kWh)")

# Energy demand
D = 60000000  # kWh/year (assumption)

# Check if hydro energy is sufficient to meet the demand
if E_h_done >= D:
    print(f"Hydro energy already installed ({E_h_done:,.2f} kWh) is sufficient to meet the energy demand ({D:,.2f} kWh).")
    print("No additional solar or wind energy is required.")
    sys.exit()
else:
    # Calculate the remaining energy demand after using hydro energy
    D = D - E_h_done

# Hydro energy production to be done
non_hydro_dams = df_NHA_data[df_NHA_data['Hydro?'] == 'N']
non_done_hydro_capacity = non_hydro_dams['Capacity'].sum()
E_h_non_done = non_done_hydro_capacity * 8760

# Calculate solar energy potential (P_s)
solar_panel_area = 1000  # Assumption: 1000 m^2 of solar panels
solar_panel_efficiency = 0.2  # Assumption: 20% efficiency
solar_loss_factor = 0.1  # Assumption: 10% loss factor
df_Boston_Solar_rolling['P_s'] = solar_panel_area * df_Boston_Solar_rolling['GHI'] * solar_panel_efficiency * (1 - solar_loss_factor)
solar_production = df_Boston_Solar_rolling['P_s'].sum()  # Total solar energy potential

# Calculate wind energy potential (P_w)
air_density = 1.225  # kg/m^3 (standard air density at sea level)
turbine_diameter = 50  # m (assumption)
turbine_efficiency = 0.7  # Assumption: 40% efficiency
swept_area = np.pi * (turbine_diameter / 2) ** 2  # m^2
df_Boston_Solar_rolling['P_w'] = 0.5 * air_density * swept_area * df_Boston_Solar_rolling['Wind Speed'] ** 3 * turbine_efficiency
wind_production = df_Boston_Solar_rolling['P_w'].sum()  # Total wind energy potential

print("The Energy generated from Solar energy in KWh:", solar_production)
print("The Energy generated from Wind energy in KWh:", wind_production)
print("The Energy generated from Hydro energy in KWh:", hydro_production)
print("Energy Demand:", D)

cost_solar = C_s * solar_production * 1000
cost_wind = C_w * wind_production
# Count the number of entries where 'Hydro?' is 'Y'
count_hydro_y = df_NHA_data[df_NHA_data['Hydro?'] == 'Y'].shape[0]
cost_hydro_non_done = C_h * count_hydro_y

# Find the cheapest combination
min_cost = float('inf')
cheapest_combination = None

# Check all possible combinations
for solar in [True, False]:
    for wind in [True, False]:
        for hydro in [True, False]:
            if not (solar or wind or hydro):
                continue

            total_energy = (solar * solar_production) + (wind * wind_production) + (hydro * E_h_non_done)
            total_cost = (solar * cost_solar) + (wind * cost_wind) + (hydro * cost_hydro_non_done)

            if total_energy >= D and total_cost < min_cost:
                min_cost = total_cost
                cheapest_combination = (solar, wind, hydro)

# Print the result
print(f"The cheapest combination to meet the energy demand of {D:,.2f} kWh is:")
if cheapest_combination[0]:
    print("Use solar energy and cost of the solar energy production:", cost_solar)
if cheapest_combination[1]:
    print("Use wind energy and the cost of wind energy production:", cost_wind)
if cheapest_combination[2]:
    print("Use additional hydro capacity and the cost of hydro energy production:", cost_hydro_non_done)
print(f"Total cost: ${min_cost:,.2f}")
